# %% [markdown]
# # 本节内容摘要

# %% [markdown]
# 权重衰退是最常见的一种处理过拟合的方法，是最广泛使用的正则化技术之一
#
# > #### 复习上一节：控制模型容量（处理过拟合相关）
# >
# > 1. 使用更少参数
# > 2. 控制每个参数（取值/可选择的值）范围较小
#
# 其中权重衰退属于第二种方法。
#
# ### 1. 使用均方范数作为硬性限制
# w向量中每一个元素的值都小于θ的根号
#
# 通常不会限制偏移b，理论上讲b表示整个数据在零点上的偏移，因此是不应该限制的，但实践中限制与否对结果都没什么影响。
#
# 小的θ意味着更强的正则项，对于相同的θ，w中元素越多则单个元素的值会越小。
#
# ### 2. 使用均方范数作为柔性限制
#
# 上文说的硬性限制在实际使用时比较麻烦，实际上常用的函数如PPT（就是正则化），其中λ是一个平滑的，不像以前的硬性限制。
#
#
# 可以通过拉格朗日乘子证明对于每个θ使得硬性限制的目标函数等价于上式。
#
# 其中带λ的这一项被称为罚(penalty)λ是超参数，控制了正则项的重要程度。
#
# 当λ = 0 时
# λ = 无穷大时
# 演示图解释
#
# ### 3. 参数更新
#
# 计算梯度
# 更新参数
# ![image-2.png](attachment:image-2.png)
#
# ### 4. 总结
#
# - 权重衰退通过L2正则项使得模型参数不会过大，从而控制模型复杂度
# - 正则项权重λ是控制模型复杂度的超参数

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 讲义

# %%
from IPython.display import display, IFrame

# 使用IFrame将PDF文件嵌入到Notebook中
pdf_path = "../PPT/part-0_16.pdf"
display(IFrame(pdf_path, width=1100, height=600))
# Out:
#         <iframe
#             width="1100"
#             height="600"
#             src="../PPT/part-0_16.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
